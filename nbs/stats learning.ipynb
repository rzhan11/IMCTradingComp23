# %% [markdown]
# # Desc
#
# - using this file to practice/learn basic stats
# - also want to learn standard time series analysis techniques

# %%
from IPython.display import display, HTML
import ipywidgets as widgets
from ipywidgets import interact
display(HTML("<style>.container { width:75% !important; }</style>"))
# Out:
# <style>.container { width:75% !important; }</style>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import statsmodels
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.ar_model import AutoReg

from sklearn.metrics import r2_score

# %% [markdown]
# # Sample autoregressive models

# %%
# acf/pacf on an autoregressive model
def ar(history, params):
    base = np.sum(np.array(history[-len(params):]) * params)
    shock = np.random.normal(loc=0, scale=1)
    return base + shock


def gen_data(n, params):
    print("gen_data", n, params)
    params = np.array(params[::-1])
    history = [0] * len(params)

    for i in range(n):
        history += [ar(history, params)]
    return np.array(history)[-n:]

# %% [markdown]
# ## Data vis

# %%
num_samples = 20000

data_df = pd.DataFrame({
    "random_walk": gen_data(num_samples, [1]), 
    "mean_revert_fast": gen_data(num_samples, [0.5]), 
    "mean_revert": gen_data(num_samples, [0.95]), 
    "mean_revert_slow": gen_data(num_samples, [0.99]), 
    "ar2": gen_data(num_samples, [0.5, -0.5]),
    "ar(2) 0.89 0.1": gen_data(num_samples, [0.89, 0.1]),
    "noise": gen_data(num_samples, [0]),
})
data_df["rw_diff"] = data_df["random_walk"] - data_df["random_walk"].shift(1).fillna(0)
data_df["mr_diff"] = data_df["mean_revert"] - data_df["mean_revert"].shift(1).fillna(0)
data_df["mr_fast_diff"] = data_df["mean_revert_fast"] - data_df["mean_revert_fast"].shift(1).fillna(0)

for col in data_df.columns:
    plt.plot(data_df[col], label=col)
    plt.title(col)
    plt.legend()
    plt.show()
# Out:
# gen_data 20000 [1]
# gen_data 20000 [0.5]
# gen_data 20000 [0.95]
# gen_data 20000 [0.99]
# gen_data 20000 [0.5, -0.5]
# gen_data 20000 [0.89, 0.1]
# gen_data 20000 [0]

# %%
plt.hist(data_df["random_walk"])
# Out:
# (array([1530.,  770., 1490., 2808., 3772.,  972.,  769., 1992., 3868.,
#         2029.]),
#  array([-240.33557289, -214.87490034, -189.41422779, -163.95355523,
#         -138.49288268, -113.03221013,  -87.57153758,  -62.11086502,
#          -36.65019247,  -11.18951992,   14.27115263]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data_df["mean_revert_fast"], bins=20)
# Out:
# (array([1.200e+01, 3.600e+01, 1.220e+02, 2.910e+02, 7.760e+02, 1.305e+03,
#         2.089e+03, 2.815e+03, 3.173e+03, 3.127e+03, 2.547e+03, 1.752e+03,
#         1.099e+03, 5.400e+02, 2.070e+02, 8.700e+01, 1.700e+01, 3.000e+00,
#         1.000e+00, 1.000e+00]),
#  array([-4.16521802, -3.69066202, -3.21610602, -2.74155001, -2.26699401,
#         -1.79243801, -1.317882  , -0.843326  , -0.36877   ,  0.10578601,
#          0.58034201,  1.05489801,  1.52945402,  2.00401002,  2.47856602,
#          2.95312203,  3.42767803,  3.90223403,  4.37679004,  4.85134604,
#          5.32590204]),
#  <BarContainer object of 20 artists>)

# %%
def check_stationary(series):
    # Copied from https://machinelearningmastery.com/time-series-data-stationary-python/

    result = adfuller(series.values)

    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))

    if (result[1] <= 0.01) & (result[4]['5%'] > result[0]):
        print("\u001b[32mStationary\u001b[0m")
    else:
        print("\x1b[31mNon-stationary\x1b[0m")

# %% [markdown]
# ## stationary checks

# %%
for col in data_df.columns:
    print("\nChecking", col)
    check_stationary(data_df[col])
# Out:
# Checking random_walk
# ADF Statistic: -1.168101
# p-value: 0.687165
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Non-stationary
#
# Checking mean_revert_fast
# ADF Statistic: -81.005293
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary
#
# Checking mean_revert
# ADF Statistic: -21.958311
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary
#
# Checking mean_revert_slow
# ADF Statistic: -9.789963
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary
#
# Checking ar2
# ADF Statistic: -97.826757
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary
#
# Checking ar(2) 0.89 0.1
# ADF Statistic: -9.796731
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary
#
# Checking noise
# ADF Statistic: -141.193733
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary
#
# Checking rw_diff
# ADF Statistic: -142.279287
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary
#
# Checking mr_diff
# ADF Statistic: -28.499607
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary
#
# Checking mr_fast_diff
# ADF Statistic: -35.355486
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary

# %% [markdown]
# ## random walk / mean reversion plots

# %%
plt.scatter(data_df["random_walk"], data_df["random_walk"].shift(10).fillna(-100), s=1)

# %%
plt.scatter(data_df["mean_revert"], data_df["mean_revert"] - data_df["mean_revert"].shift(10).fillna(-10), s=1)

# %%
df = data_df[["mean_revert"]].join(data_df["mean_revert"].shift(-1) - data_df["mean_revert"], rsuffix="_diff").dropna()
plt.scatter(df["mean_revert"], df["mean_revert_diff"], s=1)
plt.scatter(df["mean_revert"], df["mean_revert"].shift(1).fillna(0), s=1)

# %%
x = data_df["mean_revert_fast"]
y = (data_df["mean_revert_fast"].shift(-1) - data_df["mean_revert_fast"]).fillna(0)
model = np.poly1d(np.polyfit(x, y, deg=1))
score = r2_score(y, model(x))
print("r2", score)
plt.scatter(x, y, s=1)
plt.scatter(x, model(x), s=1)
# Out:
# r2 0.247044931873455

# %% [markdown]
# ## ACF / PACF plots

# %%
num_tests = len(data_df.columns)

fig, axs = plt.subplots(num_tests, 2, figsize=(10, 2 * num_tests))

for index, col in enumerate(data_df.columns):

    # plot data_a
    axrow = axs[index]
    
    ax = axrow[0]
    plot_acf(data_df[col], ax=ax, lags=40)
    ax.set_title(ax.get_title() + f" {col}")
    
    ax = axrow[1]
    plot_pacf(data_df[col], method="ywm", ax=ax, lags=40)
#     ax.set_ylim(-0.1, 0.1)



plt.tight_layout()
plt.show()

# %%
for col in data_df.columns:
    print(col)
    ar_model = AutoReg(data_df[col], lags=2).fit()
    print(ar_model.summary())
    print("\n"*3)
# Out:
# random_walk
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:            random_walk   No. Observations:                20000
# Model:                     AutoReg(2)   Log Likelihood              -28445.247
# Method:               Conditional MLE   S.D. of innovations              1.003
# Date:                Sat, 25 Mar 2023   AIC                          56898.493
# Time:                        17:21:34   BIC                          56930.107
# Sample:                             2   HQIC                         56908.836
#                                 20000
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0126      0.012     -1.022      0.307      -0.037       0.012
# random_walk.L1     0.9938      0.007    140.541      0.000       0.980       1.008
# random_walk.L2     0.0061      0.007      0.859      0.390      -0.008       0.020
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0001           +0.0000j            1.0001            0.0000
# AR.2         -164.6255           +0.0000j          164.6255            0.5000
# -----------------------------------------------------------------------------
#
#
#
#
# mean_revert_fast
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:       mean_revert_fast   No. Observations:                20000
# Model:                     AutoReg(2)   Log Likelihood              -28372.604
# Method:               Conditional MLE   S.D. of innovations              1.000
# Date:                Sat, 25 Mar 2023   AIC                          56753.207
# Time:                        17:21:34   BIC                          56784.821
# Sample:                             2   HQIC                         56763.550
#                                 20000
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0063      0.007      0.897      0.370      -0.008       0.020
# mean_revert_fast.L1     0.5076      0.007     71.787      0.000       0.494       0.522
# mean_revert_fast.L2    -0.0036      0.007     -0.510      0.610      -0.017       0.010
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.9983           +0.0000j            1.9983            0.0000
# AR.2          138.6258           +0.0000j          138.6258            0.0000
# -----------------------------------------------------------------------------
#
#
#
#
# mean_revert
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:            mean_revert   No. Observations:                20000
# Model:                     AutoReg(2)   Log Likelihood              -28354.047
# Method:               Conditional MLE   S.D. of innovations              0.999
# Date:                Sat, 25 Mar 2023   AIC                          56716.095
# Time:                        17:21:34   BIC                          56747.709
# Sample:                             2   HQIC                         56726.438
#                                 20000
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0016      0.007     -0.230      0.818      -0.015       0.012
# mean_revert.L1     0.9521      0.007    134.649      0.000       0.938       0.966
# mean_revert.L2     0.0008      0.007      0.108      0.914      -0.013       0.015
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0494           +0.0000j            1.0494            0.0000
# AR.2        -1244.5673           +0.0000j         1244.5673            0.5000
# -----------------------------------------------------------------------------
#
#
#
#
# mean_revert_slow
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:       mean_revert_slow   No. Observations:                20000
# Model:                     AutoReg(2)   Log Likelihood              -28328.890
# Method:               Conditional MLE   S.D. of innovations              0.998
# Date:                Sat, 25 Mar 2023   AIC                          56665.780
# Time:                        17:21:34   BIC                          56697.394
# Sample:                             2   HQIC                         56676.123
#                                 20000
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0022      0.007      0.309      0.757      -0.012       0.016
# mean_revert_slow.L1     0.9965      0.007    140.943      0.000       0.983       1.010
# mean_revert_slow.L2    -0.0061      0.007     -0.868      0.386      -0.020       0.008
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0098           +0.0000j            1.0098            0.0000
# AR.2          161.4250           +0.0000j          161.4250            0.0000
# -----------------------------------------------------------------------------
#
#
#
#
# ar2
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                    ar2   No. Observations:                20000
# Model:                     AutoReg(2)   Log Likelihood              -28237.881
# Method:               Conditional MLE   S.D. of innovations              0.993
# Date:                Sat, 25 Mar 2023   AIC                          56483.761
# Time:                        17:21:34   BIC                          56515.375
# Sample:                             2   HQIC                         56494.104
#                                 20000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0048      0.007     -0.690      0.490      -0.019       0.009
# ar2.L1         0.5046      0.006     82.110      0.000       0.493       0.517
# ar2.L2        -0.4948      0.006    -80.530      0.000      -0.507      -0.483
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.5098           -1.3270j            1.4216           -0.1916
# AR.2            0.5098           +1.3270j            1.4216            0.1916
# -----------------------------------------------------------------------------
#
#
#
#
# ar(2) 0.89 0.1
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:         ar(2) 0.89 0.1   No. Observations:                20000
# Model:                     AutoReg(2)   Log Likelihood              -28391.535
# Method:               Conditional MLE   S.D. of innovations              1.001
# Date:                Sat, 25 Mar 2023   AIC                          56791.071
# Time:                        17:21:34   BIC                          56822.684
# Sample:                             2   HQIC                         56801.414
#                                 20000
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.0040      0.007      0.559      0.576      -0.010       0.018
# ar(2) 0.89 0.1.L1     0.8876      0.007    126.185      0.000       0.874       0.901
# ar(2) 0.89 0.1.L2     0.1018      0.007     14.467      0.000       0.088       0.116
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0097           +0.0000j            1.0097            0.0000
# AR.2           -9.7318           +0.0000j            9.7318            0.5000
# -----------------------------------------------------------------------------
#
#
#
#
# noise
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                  noise   No. Observations:                20000
# Model:                     AutoReg(2)   Log Likelihood              -28494.723
# Method:               Conditional MLE   S.D. of innovations              1.006
# Date:                Sat, 25 Mar 2023   AIC                          56997.445
# Time:                        17:21:34   BIC                          57029.059
# Sample:                             2   HQIC                         57007.788
#                                 20000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0075      0.007     -1.058      0.290      -0.021       0.006
# noise.L1       0.0014      0.007      0.191      0.848      -0.013       0.015
# noise.L2       0.0054      0.007      0.769      0.442      -0.008       0.019
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           13.4339           +0.0000j           13.4339            0.0000
# AR.2          -13.6828           +0.0000j           13.6828            0.5000
# -----------------------------------------------------------------------------
#
#
#
#
# rw_diff
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                rw_diff   No. Observations:                20000
# Model:                     AutoReg(2)   Log Likelihood              -28445.891
# Method:               Conditional MLE   S.D. of innovations              1.004
# Date:                Sat, 25 Mar 2023   AIC                          56899.781
# Time:                        17:21:34   BIC                          56931.395
# Sample:                             2   HQIC                         56910.124
#                                 20000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0009      0.007     -0.124      0.901      -0.015       0.013
# rw_diff.L1    -0.0061      0.007     -0.864      0.387      -0.020       0.008
# rw_diff.L2     0.0018      0.007      0.251      0.802      -0.012       0.016
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -22.0604           +0.0000j           22.0604            0.5000
# AR.2           25.4985           +0.0000j           25.4985            0.0000
# -----------------------------------------------------------------------------
#
#
#
#
# mr_diff
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                mr_diff   No. Observations:                20000
# Model:                     AutoReg(2)   Log Likelihood              -28583.756
# Method:               Conditional MLE   S.D. of innovations              1.010
# Date:                Sat, 25 Mar 2023   AIC                          57175.512
# Time:                        17:21:34   BIC                          57207.126
# Sample:                             2   HQIC                         57185.855
#                                 20000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.007      0.038      0.970      -0.014       0.014
# mr_diff.L1    -0.0247      0.007     -3.496      0.000      -0.039      -0.011
# mr_diff.L2    -0.0163      0.007     -2.305      0.021      -0.030      -0.002
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.7583           -7.7964j            7.8332           -0.2654
# AR.2           -0.7583           +7.7964j            7.8332            0.2654
# -----------------------------------------------------------------------------
#
#
#
#
# mr_fast_diff
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:           mr_fast_diff   No. Observations:                20000
# Model:                     AutoReg(2)   Log Likelihood              -30213.638
# Method:               Conditional MLE   S.D. of innovations              1.096
# Date:                Sat, 25 Mar 2023   AIC                          60435.276
# Time:                        17:21:34   BIC                          60466.889
# Sample:                             2   HQIC                         60445.619
#                                 20000
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0002      0.008      0.022      0.983      -0.015       0.015
# mr_fast_diff.L1    -0.2916      0.007    -42.033      0.000      -0.305      -0.278
# mr_fast_diff.L2    -0.1933      0.007    -27.867      0.000      -0.207      -0.180
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.7542           -2.1456j            2.2742           -0.3038
# AR.2           -0.7542           +2.1456j            2.2742            0.3038
# -----------------------------------------------------------------------------

# %% [markdown]
# # Analysis for IMC

# %% [markdown]
# ## Data reading

# %%
# parameters
_round_num = 3
_time_per_day = 1000000

# %%
def get_file_trades(day):
    fname = f"../data/round{_round_num}/trades_round_{_round_num}_day_{day}_nn.csv"
    print("fname", fname)
    return pd.read_csv(fname, sep=";")


def get_file_prices(day):
    fname = f"../data/round{_round_num}/prices_round_{_round_num}_day_{day}.csv"
    print("fname", fname)
    return pd.read_csv(fname, sep=";")

def get_symbol_prices(symbol, days):
    """ Returns DataFrame containing all price data for specified symbol, over the specified 'days'
    If symbol is None, don't filter on symbol
    """
    
    data = []
    for day in days:
        price_df = get_file_prices(day)
        data += [price_df]
    
    # concat
    price_df = pd.concat(data)
    
    # rename "bid" to "buy"
    # rename "ask" to "sell"
    price_df = price_df.rename({col: col.replace("bid", "buy") for col in price_df.columns if "bid" in col}, axis=1)
    price_df = price_df.rename({col: col.replace("ask", "sell") for col in price_df.columns if "ask" in col}, axis=1)
    price_df = price_df.rename({"timestamp": "time", "product": "symbol"}, axis=1)
    
    if symbol is not None:
        # filter for specific symbol
        price_df = price_df[price_df["symbol"] == symbol]
    
    # fix times, sort by time and reindex
    price_df["time"] = price_df["time"] + price_df["day"] * _time_per_day
    price_df = price_df.sort_values(by="time").reset_index(drop=True)
    
    return price_df

def get_all_mids(days):
    price_df = get_symbol_prices(symbol=None, days=days)
    
    symbols = set(price_df["symbol"])
    
    price_df["mid"] = (price_df["buy_price_1"] + price_df["sell_price_1"]) / 2
    
    return price_df[["time", "symbol", "mid"]].copy()

# %%
def get_book_large_size(price_df, side):
    """ 
    side = 'buy' or 'sell' 
    
    Returns prices, sizes
    """
    
    book_range = list(range(1, 3+1))
    
    # get bids
    bid_sizes = price_df[[f"{side}_volume_{i}" for i in book_range]]
    bid_prices = price_df[[f"{side}_price_{i}" for i in book_range]]

    # replace nan with -1
    bid_sizes = bid_sizes.replace(np.nan, -1)

    # find inds
    inds = np.argmax(bid_sizes.to_numpy(), axis=1)

    # filter to keep largest bids
    bid_prices = bid_prices.to_numpy()[np.arange(len(bid_prices)), inds]
    bid_sizes = bid_sizes.to_numpy()[np.arange(len(bid_sizes)), inds]
    
    # create dataframe
    df = pd.DataFrame([bid_prices, bid_sizes]).T
    df.columns = [f"{side}_price", f"{side}_size"]
    df["time"] = price_df["time"].reset_index()["time"]
    
    return df


def get_whale_quotes(price_df):
    # get big buy/sell quotes
    buy_df = get_book_large_size(price_df, "buy")
    sell_df = get_book_large_size(price_df, "sell")

    # create big quote_df
    quote_df = pd.merge(buy_df, sell_df, on="time")
    quote_df["mid_price"] = (quote_df["buy_price"] + quote_df["sell_price"]) / 2
    quote_df["spread"] = quote_df["sell_price"] - quote_df["buy_price"]

    return quote_df

# %%
def scatter_noise(x, y, xnoise=0.1, ynoise=0.1, s=0.1, label=None):
    xp = x + np.random.normal(scale=xnoise, size=len(x))
    yp = y + np.random.normal(scale=ynoise, size=len(y))
    
    plt.scatter(
        xp, yp, 
        s=s, 
        label=label,
    )

# %% [markdown]
# ## Bananas

# %%
_symbol = "BANANAS"
_day_range = [-1, 0, 1]

price_df = get_symbol_prices(_symbol, _day_range)

mid_df = get_all_mids(_day_range)
mid_df = mid_df[mid_df["symbol"] == _symbol].reset_index(drop=True)
plt.plot(mid_df["time"], mid_df["mid"])

quote_df = get_whale_quotes(price_df)
quote_df["mid"] = (quote_df["buy_price"] + quote_df["sell_price"]) / 2
plt.plot(quote_df["time"], quote_df["mid"])

plt.show()

plt.hist(quote_df["mid"], bins=20)
# Out:
# fname ../data/round3/prices_round_3_day_-1.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[145], line 4
#       1 _symbol = "BANANAS"
#       2 _day_range = [-1, 0, 1]
# ----> 4 price_df = get_symbol_prices(_symbol, _day_range)
#       6 mid_df = get_all_mids(_day_range)
#       7 mid_df = mid_df[mid_df["symbol"] == _symbol].reset_index(drop=True)
#
# Cell In[142], line 19, in get_symbol_prices(symbol, days)
#      17 data = []
#      18 for day in days:
# ---> 19     price_df = get_file_prices(day)
#      20     data += [price_df]
#      22 # concat
#
# Cell In[142], line 10, in get_file_prices(day)
#       8 fname = f"../data/round{_round_num}/prices_round_{_round_num}_day_{day}.csv"
#       9 print("fname", fname)
# ---> 10 return pd.read_csv(fname, sep=";")
#
# File ~/opt/miniconda3/envs/quant/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/quant/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/quant/lib/python3.9/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/miniconda3/envs/quant/lib/python3.9/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/opt/miniconda3/envs/quant/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/miniconda3/envs/quant/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/opt/miniconda3/envs/quant/lib/python3.9/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/round3/prices_round_3_day_-1.csv'

# %% [markdown]
# #### BANANAS are non-stationary

# %%
all_vals = {
    f"{_symbol} mid_raw": mid_df["mid"],
    f"{_symbol} mid_raw diff": (mid_df["mid"] - mid_df["mid"].shift(1)).fillna(0),
    f"{_symbol} mid_whale": quote_df["mid"],
    f"{_symbol} mid_whale diff": (quote_df["mid"] - quote_df["mid"].shift(1)).fillna(0),
}

fig, axs = plt.subplots(len(all_vals), 2, figsize=(10, 3 * len(all_vals)))

for index, (name, vals) in enumerate(all_vals.items()):

    print("\n" + name)
    # check non stationary
    check_stationary(vals)

    axrow = axs[index]

    ax = axrow[0]
    plot_acf(vals, ax=ax, lags=40)
    ax.set_title(ax.get_title() + " " + name)

    ax = axrow[1]
    plot_pacf(vals, method="ywm", ax=ax, lags=40)
    # ax.set_ylim(-0.1, 0.1)    

plt.tight_layout()
plt.show()
# Out:
# BANANAS mid_raw
# ADF Statistic: -0.973557
# p-value: 0.762786
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Non-stationary
#
# BANANAS mid_raw diff
# ADF Statistic: -64.459305
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary
#
# BANANAS mid_whale
# ADF Statistic: -1.002676
# p-value: 0.752287
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Non-stationary
#
# BANANAS mid_whale diff
# ADF Statistic: -113.236970
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary

# %% [markdown]
# ## Pairs trading

# %%
_day_range = [0, 1, 2]
# _day_range = [-1, 0, 1]

coco_price_df = get_symbol_prices("COCONUTS", _day_range)
pina_price_df = get_symbol_prices("PINA_COLADAS", _day_range)

coco_df = get_whale_quotes(coco_price_df)
pina_df = get_whale_quotes(pina_price_df)
pair_df = pd.DataFrame({
    "mid_coco": coco_df["mid_price"], 
    "mid_pina": pina_df["mid_price"],
    "time": pina_df["time"],
})

fig, ax = plt.subplots()

ax.plot(pair_df["time"], pair_df["mid_coco"], color="blue", label="coco")
ax.legend(loc=1)

ax2 = ax.twinx()

ax2.plot(pair_df["time"], pair_df["mid_pina"], color="orange", label="pina")
ax2.legend(loc=2)
# Out:
# fname ../data/round3/prices_round_3_day_0.csv
# fname ../data/round3/prices_round_3_day_1.csv
# fname ../data/round3/prices_round_3_day_2.csv
# fname ../data/round3/prices_round_3_day_0.csv
# fname ../data/round3/prices_round_3_day_1.csv
# fname ../data/round3/prices_round_3_day_2.csv

# %% [markdown]
# ## plot first diffs over time

# %%
plt.scatter(pair_df["mid_coco"].diff(1), pair_df["mid_pina"].diff(1))

# %%
plt.figure(figsize=(12, 3))

all_x = pair_df["mid_coco"].diff(1).dropna()
all_y = pair_df["mid_pina"].diff(1).dropna()

xlim = all_x.min(), all_x.max()
ylim = all_y.min(), all_y.max()

big_model = np.poly1d(np.polyfit(all_x, all_y, deg=1))
print("big_model", big_model.coef)

### params
chunk_size = 100


model_data = []

for i in range(len(pair_df) - chunk_size):

    lb = i
    ub = lb + chunk_size

    df = pair_df.iloc[lb:ub]

    x = df["mid_coco"].diff(1).dropna()
    y = df["mid_pina"].diff(1).dropna()

    inds = x.index.intersection(y.index)

    x = x[inds]
    y = y[inds]

    # fit line
    model = np.poly1d(np.polyfit(x, y, deg=1))
    model_data += [{
        "m": model.coef[0],
        "b": model.coef[1],
        "r2": r2_score(y, model(x)),
    }]

#     if i < 5:
#         plt.subplot(121)
#         plt.hist(x, bins=50)
#         plt.hist(y, bins=50, alpha=0.5)

#         plt.subplot(122)
#         plt.scatter(x, y, s=1)
#         plt.plot(x, model(x), color="red", label="fit")
#         plt.plot(x, model(x), color="black", label="fit")
#         plt.xlim(xlim)
#         plt.ylim(ylim)
        
#         plt.show()

#         print("model", model.coef)
model_df = pd.DataFrame(model_data)
# Out:
# big_model [ 1.51496779 -0.0023488 ]

# %%
plt.plot(model_df["r2"], label="r2")
plt.plot(model_df["m"], label="m")
plt.plot(model_df["b"], label="b")
plt.axhline(y=1.5)

plt.legend()

# %%
check_stationary(model_df["m"])
# Out:
# ADF Statistic: -15.342639
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary

# %%
# get errors
error = pair_df["mid_pina"] - pair_df["mid_coco"] * 1.5 - 3000
error_df = pd.DataFrame({"error": error})

# check stationarity of the error
check_stationary(error_df["error"])

# get `change` stats
error_df["above"] = error_df["error"] > 0
error_df["change"] = error_df["above"] != error_df["above"].shift(1)
# Out:
# ADF Statistic: -4.361701
# p-value: 0.000347
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary

# %%
plt.plot(error_df["error"])

# %%
low, high = 0, 0

bounds = []

for index, row in error_df.iterrows():
    if row["change"]:
        bounds += [(low, high)]
        low, high = 0, 0
        
    # record max error
    low = min(low, row["error"])
    high = max(low, row["error"])
    
    
df = pd.DataFrame(bounds, columns=["low", "high"])
df["bound"] = np.maximum(df["low"].abs(), df["high"].abs())

# get number of times we reach each threshold
freq_df = df.groupby("bound")[["low"]].count().rename({"low": "count"}, axis=1)
freq_df = freq_df.sort_index(ascending=False).cumsum().reset_index()
freq_df["pnl"] = freq_df["bound"] * freq_df["count"]

# %%
plt.plot(freq_df["bound"], freq_df["pnl"])

# %%
freq_df.sort_values(by="pnl", ascending=False)
# Out:
#     bound  count     pnl
# 25  14.25     36  513.00
# 27  12.75     40  510.00
# 26  13.25     38  503.50
# 24  15.25     33  503.25
# 28  11.25     41  461.25
# 23  15.75     29  456.75
# 22  16.25     28  455.00
# 21  16.75     27  452.25
# 29  10.75     42  451.50
# 20  17.25     26  448.50
# 32   8.75     50  437.50
# 31   9.25     47  434.75
# 18  19.75     22  434.50
# 19  18.75     23  431.25
# 33   8.25     52  429.00
# 30   9.75     44  429.00
# 17  20.25     21  425.25
# 34   7.75     54  418.50
# 16  20.75     20  415.00
# 15  22.25     18  400.50
# 35   7.25     55  398.75
# 36   6.25     63  393.75
# 45   2.25    173  389.25
# 39   5.25     74  388.50
# 14  24.25     16  388.00
# 46   1.75    221  386.75
# 37   5.75     67  385.25
# 43   3.25    117  380.25
# 40   4.75     80  380.00
# 44   2.75    138  379.50
# 13  25.25     15  378.75
# 38   5.50     68  374.00
# 42   3.75     96  360.00
# 41   4.25     84  357.00
# 47   1.25    283  353.75
# 9   34.75     10  347.50
# 12  26.25     13  341.25
# 10  30.25     11  332.75
# 6   46.75      7  327.25
# 11  27.25     12  327.00
# 8   35.75      9  321.75
# 5   52.75      6  316.50
# 7   37.75      8  302.00
# 49   0.75    397  297.75
# 48   1.00    284  284.00
# 4   53.75      5  268.75
# 3   56.75      4  227.00
# 50   0.50    401  200.50
# 2   57.75      3  173.25
# 51   0.25    542  135.50
# 1   64.25      2  128.50
# 0   72.75      1   72.75
# 52   0.00    543    0.00

# %%
plt.plot(error)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))
plot_acf(error, ax=axs[0])
plot_pacf(error, ax=axs[1])

# %%
plt.figure(figsize=(10, 3))
plt.subplot(1, 2, 1)
plt.hist(pair_df["mid_coco"])
plt.subplot(1, 2, 2)
plt.hist(pair_df["mid_pina"])
# Out:
# (array([1172., 7595., 6912., 3416., 1402., 3079., 1980., 1563., 1809.,
#         1072.]),
#  array([14774.5, 14822.1, 14869.7, 14917.3, 14964.9, 15012.5, 15060.1,
#         15107.7, 15155.3, 15202.9, 15250.5]),
#  <BarContainer object of 10 artists>)

# %%
all_vals = {
    f"mid_pina": pair_df["mid_pina"],
    f"mid_pina diff": (pair_df["mid_pina"] - pair_df["mid_pina"].shift(1)).fillna(0),
    f"mid_coco": pair_df["mid_coco"],
    f"mid_coco diff": (pair_df["mid_coco"] - pair_df["mid_coco"].shift(1)).fillna(0),
}

fig, axs = plt.subplots(len(all_vals), 2, figsize=(10, 3 * len(all_vals)))

for index, (name, vals) in enumerate(all_vals.items()):

    print("\n" + name)
    # check non stationary
    check_stationary(vals)

    axrow = axs[index]

    ax = axrow[0]
    plot_acf(vals, ax=ax, lags=40)
    ax.set_title(ax.get_title() + " " + name)

    ax = axrow[1]
    plot_pacf(vals, method="ywm", ax=ax, lags=40)
    # ax.set_ylim(-0.1, 0.1)    

plt.tight_layout()
plt.show()
# Out:
# mid_pina
# ADF Statistic: -2.272511
# p-value: 0.180987
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Non-stationary
#
# mid_pina diff
# ADF Statistic: -173.425018
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary
#
# mid_coco
# ADF Statistic: -1.882370
# p-value: 0.340400
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Non-stationary
#
# mid_coco diff
# ADF Statistic: -190.776939
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Stationary

# %%
ar_model = AutoReg(pair_df["mid_coco"].diff(1).fillna(0), lags=2).fit()
ar_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:               mid_coco   No. Observations:                30000
# Model:                     AutoReg(2)   Log Likelihood              -39100.865
# Method:               Conditional MLE   S.D. of innovations              0.891
# Date:                Sat, 25 Mar 2023   AIC                          78209.731
# Time:                        17:22:27   BIC                          78242.966
# Sample:                             2   HQIC                         78220.395
#                                 30000
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0075      0.005     -1.449      0.147      -0.018       0.003
# mid_coco.L1    -0.0969      0.006    -16.786      0.000      -0.108      -0.086
# mid_coco.L2    -0.0054      0.006     -0.928      0.353      -0.017       0.006
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -9.0407          -10.2389j           13.6590           -0.3651
# AR.2           -9.0407          +10.2389j           13.6590            0.3651
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# ### Relative value analysis

# %%
pair_df["rv"] = pair_df["mid_pina"] / pair_df["mid_coco"]
pair_df["rel_diff"] = pair_df["mid_pina"] - pair_df["mid_coco"] - 7000

# %%
all_vals = {
    f"rv": pair_df.iloc[:1000]["rv"],
    f"pina - coco": pair_df.iloc[:1000]["rel_diff"],
}

fig, axs = plt.subplots(len(all_vals), 2, figsize=(10, 3 * len(all_vals)))

for index, (name, vals) in enumerate(all_vals.items()):

    print("\n" + name)
    # check non stationary
    check_stationary(vals)

    axrow = axs[index]

    ax = axrow[0]
    plot_acf(vals, ax=ax, lags=40)
    ax.set_title(ax.get_title() + " " + name)

    ax = axrow[1]
    plot_pacf(vals, method="ywm", ax=ax, lags=40)
    # ax.set_ylim(-0.1, 0.1)    

plt.tight_layout()
plt.show()
# Out:
# rv
# ADF Statistic: -1.300984
# p-value: 0.628722
# Critical Values:
# 	1%: -3.437
# 	5%: -2.864
# 	10%: -2.568
# Non-stationary
#
# pina - coco
# ADF Statistic: -1.574049
# p-value: 0.496615
# Critical Values:
# 	1%: -3.437
# 	5%: -2.864
# 	10%: -2.568
# Non-stationary

# %%
ar_model = AutoReg(pair_df["rv"], lags=3).fit()
ar_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                     rv   No. Observations:                30000
# Model:                     AutoReg(3)   Log Likelihood              212201.330
# Method:               Conditional MLE   S.D. of innovations              0.000
# Date:                Sat, 25 Mar 2023   AIC                        -424392.660
# Time:                        17:22:27   BIC                        -424351.116
# Sample:                             3   HQIC                       -424379.330
#                                 30000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.001      3.680      0.000       0.001       0.003
# rv.L1          0.8879      0.006    153.791      0.000       0.877       0.899
# rv.L2          0.0978      0.008     12.698      0.000       0.083       0.113
# rv.L3          0.0133      0.006      2.309      0.021       0.002       0.025
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0009           -0.0000j            1.0009           -0.0000
# AR.2           -4.1678           -7.5882j            8.6574           -0.3299
# AR.3           -4.1678           +7.5882j            8.6574            0.3299
# -----------------------------------------------------------------------------
# """

# %%
plt.plot(gen_data(1000, [0.8893, 0.1096]))
# Out:
# gen_data 1000 [0.8893, 0.1096]

# %%
plt.plot(pair_df["rv"].loc[:])
plt.plot(ar_model.predict(start=0, end=30000, dynamic=2000))

# %%
plt.hist(pair_df["rv"], bins=20)
# Out:
# (array([ 118.,  303.,  604.,  914., 1614., 2549., 3795., 3578., 3471.,
#         3499., 2512., 2060., 1980., 1068.,  642.,  284.,  360.,  265.,
#          266.,  118.]),
#  array([1.86533093, 1.86659756, 1.86786419, 1.86913081, 1.87039744,
#         1.87166407, 1.87293069, 1.87419732, 1.87546395, 1.87673057,
#         1.8779972 , 1.87926383, 1.88053045, 1.88179708, 1.88306371,
#         1.88433033, 1.88559696, 1.88686359, 1.88813021, 1.88939684,
#         1.89066347]),
#  <BarContainer object of 20 artists>)

# %%
plt.scatter(pair_df["rv"], -1 * pair_df["rv"].diff(-1), s=1)

# %% [markdown]
# ## Rel diff plot of COCO vs PINA

# %%
model = np.poly1d(np.polyfit(pair_df.index, pair_df["rel_diff"], deg=1))
plt.plot(pair_df["rel_diff"])
plt.plot(model(pair_df.index))

# %%
plt.plot(pair_df["rv"])

# %%
pair_df
# Out:
#        mid_coco  mid_pina     time        rv  rel_diff
# 0        8114.5   15226.5        0  1.876456     112.0
# 1        8114.5   15224.5      100  1.876209     110.0
# 2        8114.5   15225.5      200  1.876332     111.0
# 3        8114.0   15225.5      300  1.876448     111.5
# 4        8112.5   15221.5      400  1.876302     109.0
# ...         ...       ...      ...       ...       ...
# 29995    7909.5   14844.0  2999500  1.876731     -65.5
# 29996    7910.5   14845.5  2999600  1.876683     -65.0
# 29997    7911.5   14845.5  2999700  1.876446     -66.0
# 29998    7912.5   14849.5  2999800  1.876714     -63.0
# 29999    7911.5   14848.5  2999900  1.876825     -63.0
#
# [30000 rows x 5 columns]

# %%
pair_df["rv"].mean()
# Out:
# 1.876367050000544
